# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import matplotlib
import os
from matplotlib.font_manager import FontProperties

label_size = 60
tick_size = 32
linewidth = 2.5
legend_size = 28
mark_size = 10
bwith = 2
# matplotlib.font_manager._rebuild()
# Assuming memory_pages_dict is your dictionary data for the control group
memory_pages_dict_cg = {}
with open('cg-B-dirty.json', 'r') as f:
    data_cg = json.load(f)

# Loop through the items in data_cg and select a subset
for i, (adder, v) in enumerate(data_cg.items()):
    if 100 < i < 200:  # Process only items from index 101 to 200
        memory_pages_dict_cg[adder] = v['isDirtyList']
    elif i > 200:
        break  # Stop the loop if index exceeds 200

# Convert dictionary data to a 2D array
data_cg = np.array(list(memory_pages_dict_cg.values()))
# Ensure all data is in numeric format
data_cg = data_cg.astype(float)

# Dictionary data for the base test group
memory_pages_dict = {}
with open('bt-B-dirty.json', 'r') as f:
    dataall = json.load(f)

# Loop through the items in dataall and select a subset
for i, (adder, v) in enumerate(dataall.items()):
    if 100 < i < 200:  # Process only items from index 101 to 200
        memory_pages_dict[adder] = v['isDirtyList'][:12]
    elif i > 200:
        break  # Stop the loop if index exceeds 200

# Convert dictionary data to a 2D array
data = np.array(list(memory_pages_dict.values()))
# Ensure all data is in numeric format
data = data.astype(float)
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.serif'] = 'Times New Roman'
matplotlib.rcParams['font.size'] = 32
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# Create a layout of 1 row and 2 columns for subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(24, 12))

# Plot heatmap on the first subplot
cbar_ax1 = sns.heatmap(data_cg, cmap="YlGnBu", cbar_kws={'label': 'Dirty Pages Density'}, ax=ax1).collections[0].colorbar
ax1.set_xlabel('Dirty Page Time Series', fontsize=label_size)
ax1.set_ylabel('Memory Pages', fontsize=label_size)
cbar_ax1.ax.set_ylabel('Dirty Pages Density', fontsize=label_size)

# Plot heatmap on the second subplot (can be replaced with a different plot)
cbar_ax2 = sns.heatmap(data, cmap="YlGnBu", cbar_kws={'label': 'Dirty Pages Density'}, ax=ax2).collections[0].colorbar
ax2.set_xlabel('Dirty Page Time Series', fontsize=label_size)
ax2.set_ylabel('Memory Pages', fontsize=label_size)
cbar_ax2.ax.set_ylabel('Dirty Pages Density', fontsize=label_size)

# Adjust the spacing between subplots
plt.tight_layout()

# Save the entire canvas as PDF and PNG
plt.savefig(os.path.join(".", "combined_hot_dirty_en.pdf"), format='pdf', bbox_inches='tight')
plt.savefig(os.path.join(".", "combined_hot_dirty_en.png"), format='png', bbox_inches='tight')
# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import matplotlib
import os

# Set general font settings
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.serif'] = 'Times New Roman'
matplotlib.rcParams['font.size'] = 32  # Default font size for all text elements
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
label_size = 44
tick_size = 38
linewidth = 2.5
legend_size = 28
mark_size = 10
bwith = 2
# Load your data
memory_pages_dict_cg = {}
with open('cg-B-dirty.json', 'r') as f:
    data_cg = json.load(f)

# Select a subset of data
for i, (adder, v) in enumerate(data_cg.items()):
    if 100 < i < 200:
        memory_pages_dict_cg[adder] = v['isDirtyList']
    elif i > 200:
        break

# Convert to numpy array and ensure float type
data_cg = np.array(list(memory_pages_dict_cg.values())).astype(float)

# Create a figure and a single subplot
fig, ax = plt.subplots(figsize=(10, 7))

# Define specific ticks for color bar
cbar_ticks = [0, 1.0]  # Specify ticks to show

# Plot heatmap
sns_heatmap = sns.heatmap(data_cg, cmap="YlGnBu", cbar_kws={'label': 'Dirty page status', 'ticks': cbar_ticks}, ax=ax)
ax.set_xlabel('Time (seconds)', fontsize=label_size)  # Set font size for x-axis label
ax.set_ylabel('Memory pages', fontsize=label_size)  # Set font size for y-axis label
# Set tick labels font size
ax.tick_params(axis='both', which='major', labelsize=24)

# Set color bar label size specifically
cbar = sns_heatmap.collections[0].colorbar
cbar.ax.set_ylabel('Memory page status', fontsize=label_size)
cbar.ax.tick_params(labelsize=tick_size)  # Font size for color bar ticks

# Adjust layout and save the figure
plt.tight_layout()
plt.savefig(os.path.join(".", "hot_dirty_cg.pdf"), format='pdf', bbox_inches='tight')
plt.savefig(os.path.join(".", "hot_dirty_cg.png"), format='png', bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import matplotlib
import os

# Set general font settings
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.serif'] = 'Times New Roman'
matplotlib.rcParams['font.size'] = 32  # Default font size for all text elements
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
label_size = 39
tick_size = 35
linewidth = 2.5
legend_size = 28
mark_size = 10
bwith = 2

# Load your data
memory_pages_dict_cg = {}
with open('cg-B-dirty.json', 'r') as f:
    data_cg = json.load(f)

# Select a subset of data
for i, (adder, v) in enumerate(data_cg.items()):
    if 100 < i < 200:
        memory_pages_dict_cg[adder] = v['isDirtyList']
    elif i > 200:
        break

# Convert to numpy array and ensure float type
data_cg = np.array(list(memory_pages_dict_cg.values())).astype(float)

# Create a figure and a single subplot
fig, ax = plt.subplots(figsize=(10, 7))

# Define specific ticks for color bar
cbar_ticks = [0, 1.0]  # Specify ticks to show

# Plot heatmap
sns_heatmap = sns.heatmap(data_cg, cmap="YlGnBu", cbar_kws={'label': 'Dirty page status', 'ticks': cbar_ticks}, ax=ax)
ax.set_xlabel('Time (seconds)', fontsize=label_size)  # Set font size for x-axis label
ax.set_ylabel('Memory pages', fontsize=label_size)  # Set font size for y-axis label

# Reduce the number of ticks on x and y axes
x_ticks = np.linspace(0, data_cg.shape[1]-1, 5, dtype=int)  # Example: 5 ticks
y_ticks = np.linspace(0, data_cg.shape[0]-1, 5, dtype=int)  # Example: 5 ticks
ax.set_xticks(x_ticks)
ax.set_yticks(y_ticks)
ax.set_xticklabels(x_ticks, fontsize=tick_size)
ax.set_yticklabels(y_ticks, fontsize=tick_size)

# Set color bar label size specifically
cbar = sns_heatmap.collections[0].colorbar
cbar.ax.set_ylabel('Memory page status', fontsize=label_size)
cbar.ax.tick_params(labelsize=tick_size)  # Font size for color bar ticks

# Adjust layout and save the figure
plt.tight_layout()
plt.savefig(os.path.join(".", "hot_dirty_cg.pdf"), format='pdf', bbox_inches='tight')
plt.savefig(os.path.join(".", "hot_dirty_cg.png"), format='png', bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import matplotlib
import os

# Set general font settings
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.serif'] = 'Times New Roman'
matplotlib.rcParams['font.size'] = 32  # Default font size for all text elements
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
label_size = 39
tick_size = 35
linewidth = 2.5
legend_size = 28
mark_size = 10
bwith = 2

# Load your data
memory_pages_dict_cg = {}
with open('bt-B-dirty.json', 'r') as f:
    data_cg = json.load(f)

# Select a subset of data
for i, (adder, v) in enumerate(data_cg.items()):
    if 100 < i < 200:
        memory_pages_dict_cg[adder] = v['isDirtyList']
    elif i > 200:
        break

# Convert to numpy array and ensure float type
data_cg = np.array(list(memory_pages_dict_cg.values())).astype(float)

# Create a figure and a single subplot
fig, ax = plt.subplots(figsize=(10, 7))

# Define specific ticks for color bar
cbar_ticks = [0, 1.0]  # Specify ticks to show

# Plot heatmap
sns_heatmap = sns.heatmap(data_cg, cmap="YlGnBu", cbar_kws={'label': 'Dirty page status', 'ticks': cbar_ticks}, ax=ax)
ax.set_xlabel('Time (seconds)', fontsize=label_size)  # Set font size for x-axis label
ax.set_ylabel('Memory pages', fontsize=label_size)  # Set font size for y-axis label

# Reduce the number of ticks on x and y axes
x_ticks = np.linspace(0, data_cg.shape[1]-1, 5, dtype=int)  # Example: 5 ticks
y_ticks = np.linspace(0, data_cg.shape[0]-1, 5, dtype=int)  # Example: 5 ticks
ax.set_xticks(x_ticks)
ax.set_yticks(y_ticks)
ax.set_xticklabels(x_ticks, fontsize=tick_size)
ax.set_yticklabels(y_ticks, fontsize=tick_size)

# Set color bar label size specifically
cbar = sns_heatmap.collections[0].colorbar
cbar.ax.set_ylabel('Memory page status', fontsize=label_size)
cbar.ax.tick_params(labelsize=tick_size)  # Font size for color bar ticks

# Adjust layout and save the figure
plt.tight_layout()
plt.savefig(os.path.join(".", "hot_dirty_bt.pdf"), format='pdf', bbox_inches='tight')
plt.savefig(os.path.join(".", "hot_dirty_bt.png"), format='png', bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import matplotlib
import os

# Set general font settings
plt.rcParams['font.family'] = 'Times New Roman'
plt.rcParams['font.serif'] = 'Times New Roman'
matplotlib.rcParams['font.size'] = 32  # Default font size for all text elements
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42
label_size = 44
tick_size = 32
linewidth = 2.5
legend_size = 28
mark_size = 10
bwith = 2
# Load your data
memory_pages_dict_cg = {}
with open('bt-B-dirty.json', 'r') as f:
    data_bt = json.load(f)

# Select a subset of data
for i, (adder, v) in enumerate(data_bt.items()):
    if 100 < i < 200:
        memory_pages_dict_cg[adder] = v['isDirtyList']
    elif i > 200:
        break

# Convert to numpy array and ensure float type
data_bt = np.array(list(memory_pages_dict_cg.values())).astype(float)

# Create a figure and a single subplot
fig, ax = plt.subplots(figsize=(10, 7))

# Define specific ticks for color bar
cbar_ticks = [0, 1.0]  # Specify ticks to show

# Plot heatmap
sns_heatmap = sns.heatmap(data_bt, cmap="YlGnBu", cbar_kws={'label': 'Dirty page indicator', 'ticks': cbar_ticks}, ax=ax)
ax.set_xlabel('Time (seconds)', fontsize=label_size)  # Set font size for x-axis label
ax.set_ylabel('Memory pages', fontsize=label_size)  # Set font size for y-axis label
# Set tick labels font size
ax.tick_params(axis='both', which='major', labelsize=24)

# Set color bar label size specifically
cbar = sns_heatmap.collections[0].colorbar
cbar.ax.set_ylabel('Dirty page indicator', fontsize=label_size)
cbar.ax.tick_params(labelsize=tick_size)  # Font size for color bar ticks

# Adjust layout and save the figure
plt.tight_layout()
plt.savefig(os.path.join(".", "hot_dirty_bt.pdf"), format='pdf', bbox_inches='tight')
plt.savefig(os.path.join(".", "hot_dirty_bt.png"), format='png', bbox_inches='tight')
plt.show()
